# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import r2_score as R2
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('china_gdp.csv')

# %%
X=df[['Year']].values
Y=df[['Value']].values

# %%
x_train, x_test, y_train, y_test = train_test_split(X , Y, test_size = 0.2, random_state=0)

# %%
model=LR()
model.fit(X,Y)
ypred=model.predict(X)

# %%
ypred
# Out:
# array([[-1.61287007e+12],
#        [-1.49991037e+12],
#        [-1.38695067e+12],
#        [-1.27399097e+12],
#        [-1.16103127e+12],
#        [-1.04807157e+12],
#        [-9.35111873e+11],
#        [-8.22152173e+11],
#        [-7.09192474e+11],
#        [-5.96232774e+11],
#        [-4.83273075e+11],
#        [-3.70313376e+11],
#        [-2.57353676e+11],
#        [-1.44393977e+11],
#        [-3.14342771e+10],
#        [ 8.15254223e+10],
#        [ 1.94485122e+11],
#        [ 3.07444821e+11],
#        [ 4.20404521e+11],
#        [ 5.33364220e+11],
#        [ 6.46323920e+11],
#        [ 7.59283619e+11],
#        [ 8.72243319e+11],
#        [ 9.85203018e+11],
#        [ 1.09816272e+12],
#        [ 1.21112242e+12],
#        [ 1.32408212e+12],
#        [ 1.43704182e+12],
#        [ 1.55000152e+12],
#        [ 1.66296121e+12],
#        [ 1.77592091e+12],
#        [ 1.88888061e+12],
#        [ 2.00184031e+12],
#        [ 2.11480001e+12],
#        [ 2.22775971e+12],
#        [ 2.34071941e+12],
#        [ 2.45367911e+12],
#        [ 2.56663881e+12],
#        [ 2.67959851e+12],
#        [ 2.79255821e+12],
#        [ 2.90551791e+12],
#        [ 3.01847761e+12],
#        [ 3.13143731e+12],
#        [ 3.24439701e+12],
#        [ 3.35735671e+12],
#        [ 3.47031641e+12],
#        [ 3.58327611e+12],
#        [ 3.69623581e+12],
#        [ 3.80919550e+12],
#        [ 3.92215520e+12],
#        [ 4.03511490e+12],
#        [ 4.14807460e+12],
#        [ 4.26103430e+12],
#        [ 4.37399400e+12],
#        [ 4.48695370e+12]])

# %%
plt.scatter(X,Y,color='blue')
label='Actual Data'
plt.plot(X,ypred,color='red')
linewidth=2
label='Linear Regression line'
plt.title('Linear Regression Model Fit')
plt.xlabel('Year')
plt.ylabel('GDP value')
plt.legend
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(Y,ypred,color='green', label='Actual vs Predicted')
plt.plot([min(Y),max(Y)],[min(Y),max(Y)],color='red', linestyle='--',label='Ideal Prediction(y=x)')
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual GDP')
plt.ylabel('Predicted GDP')
plt.legend()
plt.grid(True)
plt.show()

# %%
r2=R2(Y,ypred)
print(f"\nR-squared(r^2) value:{r2:.4f}")
# Out:
# R-squared(r^2) value:0.5240
